# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %pip install prophet
from prophet import Prophet
# Out:
# Requirement already satisfied: prophet in c:\users\alexa\appdata\local\programs\python\python313\lib\site-packages (1.2.1)
# Requirement already satisfied: cmdstanpy>=1.0.4 in c:\users\alexa\appdata\local\programs\python\python313\lib\site-packages (from prophet) (1.3.0)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\alexa\appdata\local\programs\python\python313\lib\site-packages (from prophet) (2.3.3)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\alexa\appdata\local\programs\python\python313\lib\site-packages (from prophet) (3.10.6)
# Requirement already satisfied: pandas>=1.0.4 in c:\users\alexa\appdata\local\programs\python\python313\lib\site-packages (from prophet) (2.3.2)
# Requirement already satisfied: holidays<1,>=0.25 in c:\users\alexa\appdata\local\programs\python\python313\lib\site-packages (from prophet) (0.86)
# Requirement already satisfied: tqdm>=4.36.1 in c:\users\alexa\appdata\local\programs\python\python313\lib\site-packages (from prophet) (4.67.1)
# Requirement already satisfied: importlib_resources in c:\users\alexa\appdata\local\programs\python\python313\lib\site-packages (from prophet) (6.5.2)
# Requirement already satisfied: python-dateutil in c:\users\alexa\appdata\roaming\python\python313\site-packages (from holidays<1,>=0.25->prophet) (2.9.0.post0)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in c:\users\alexa\appdata\local\programs\python\python313\lib\site-packages (from cmdstanpy>=1.0.4->prophet) (0.5.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\alexa\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\alexa\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\alexa\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=2.0.0->prophet) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\alexa\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\alexa\appdata\roaming\python\python313\site-packages (from matplotlib>=2.0.0->prophet) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\alexa\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=2.0.0->prophet) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\alexa\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=2.0.0->prophet) (3.2.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\alexa\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.0.4->prophet) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\alexa\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.0.4->prophet) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\alexa\appdata\roaming\python\python313\site-packages (from python-dateutil->holidays<1,>=0.25->prophet) (1.17.0)
# Requirement already satisfied: colorama in c:\users\alexa\appdata\roaming\python\python313\site-packages (from tqdm>=4.36.1->prophet) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import train_test_split

# %%
# %pip install fredapi
from fredapi import Fred
# Out:
# Requirement already satisfied: fredapi in c:\users\alexa\appdata\local\programs\python\python313\lib\site-packages (0.5.2)
# Requirement already satisfied: pandas in c:\users\alexa\appdata\local\programs\python\python313\lib\site-packages (from fredapi) (2.3.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\alexa\appdata\local\programs\python\python313\lib\site-packages (from pandas->fredapi) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\alexa\appdata\roaming\python\python313\site-packages (from pandas->fredapi) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\alexa\appdata\local\programs\python\python313\lib\site-packages (from pandas->fredapi) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\alexa\appdata\local\programs\python\python313\lib\site-packages (from pandas->fredapi) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\alexa\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas->fredapi) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# #### **Load CSV files such as, countyData.csv, nysData.csv, propertyTaxPerCounty10years.csv**

# %%
county_data = pd.read_csv('finalProjData/countyData.csv')

# %%
nys_data = pd.read_csv('finalProjData/nysData.csv')

# %%
tax = pd.read_csv('finalProjData/propertyTaxPerCounty10years.csv')

# %% [markdown]
# #### **Load NYSsingleBedCountyDF.csv and NYSsingleFamilyMetroDF.csv**

# %%
county_prices = pd.read_csv('finalProjData/NYSsingleBedCountyDF.csv')

# %%
metro = pd.read_csv('finalProjData/NYSsingleFamilyMetroDF.csv')

# %% [markdown]
# #### **Mortgge rate by API from FRED**

# %%
fred = Fred(api_key='bd2983759a4cf1e15823ed3442667fb4') # it's the key from https://fredaccount.stlouisfed.org/apikey
rates = fred.get_series('MORTGAGE30US', observation_start='2015-01-01') #mortgage rate from 2015 to 2025
df_rates = pd.DataFrame(rates, columns=['Mortgage Rate']) # DataFrame for the fred data

# %% [markdown]
# #### **Clean Data Metro**

# %%
metro_long = metro.melt(id_vars=['RegionID', 'SizeRank', 'RegionName', 'RegionType', 'StateName'],
                        var_name='Date',
                        value_name='HomePrice')

metro_long["Date"] = pd.to_datetime(metro_long["Date"])
metro_long = metro_long.dropna()
metro_long.head()
# Out:
#    RegionID  SizeRank        RegionName RegionType StateName       Date  \
# 0    394913         1      New York, NY        msa        NY 2015-01-31
# 1    394425        50       Buffalo, NY        msa        NY 2015-01-31
# 2    395031        52     Rochester, NY        msa        NY 2015-01-31
# 3    394308        64        Albany, NY        msa        NY 2015-01-31
# 4    845159        86  Poughkeepsie, NY        msa        NY 2015-01-31
#
#      HomePrice
# 0  1986.778076
# 1  1022.171678
# 2  1058.697013
# 3  1271.508966
# 4  1606.776133

# %% [markdown]
# ### **Clean COUNTY HOME PRICE DATA**

# %%
county_long = county_prices.melt(
    id_vars=["RegionID", "SizeRank", "RegionName", "RegionType", "StateName",
            "State", "Metro", "StateCodeFIPS", "MunicipalCodeFIPS"],
    var_name="PriceDate",
    value_name="HomePrice"
)

county_long["PriceDate"] = pd.to_datetime(county_long["PriceDate"])
county_long = county_long.dropna()


county_long["County"] = county_long["RegionName"].str.replace(" County", "")
county_long["Year"] = county_long["PriceDate"].dt.year
county_long["Month"] = county_long["PriceDate"] + pd.offsets.MonthEnd(0)

# %% [markdown]
# ### **CLEAN 3 — PROPERTY TAX DATA**

# %%
tax_long = tax.melt(id_vars=['County'], var_name='Year', value_name='TaxAmount')
tax_long['TaxDate'] = pd.to_datetime(tax_long['Year'], format='%Y')
tax_clean = tax_long.drop(columns=["Year"])
tax_clean["Year"] = pd.to_datetime(tax_clean["TaxDate"]).dt.year
tax_clean.head()
# Out:
#         County  TaxAmount    TaxDate  Year
# 0       Albany     3526.0 2015-01-01  2015
# 1     Allegany     1959.0 2015-01-01  2015
# 2        Bronx     2653.0 2015-01-01  2015
# 3       Broome     2417.0 2015-01-01  2015
# 4  Cattaraugus     2054.0 2015-01-01  2015

# %% [markdown]
# #### **CLEAN 4 — COUNTY COST OF LIVING (RENT PROXY)**

# %%
county_data["RentDate"] = pd.to_datetime("2024-01-01")
county_rent = county_data[["RentDate", "County", "Housing"]].copy()

# Convert annual housing cost to monthly rent
county_rent["MonthlyRent"] = county_rent["Housing"] / 12

county_rent.head()
# Out:
#     RentDate       County  Housing  MonthlyRent
# 0 2024-01-01       Albany  13098.0  1091.500000
# 1 2024-01-01     Allegany   8435.0   702.916667
# 2 2024-01-01        Bronx  21130.0  1760.833333
# 3 2024-01-01       Broome  10472.0   872.666667
# 4 2024-01-01  Cattaraugus   8833.0   736.083333

# %% [markdown]
# #### **CLEAN 5 MERGE ALL COUNTY-LEVEL DATA INTO ONE MASTER DATASET**

# %%
#Prepare mortgage rate dataframe
df_rates = df_rates.reset_index()
df_rates = df_rates.rename(columns={"index": "RateDate"})
df_rates["RateDate"] = pd.to_datetime(df_rates["RateDate"])

# Convert weekly mortgage data to monthly average
df_rates = df_rates.resample("M", on="RateDate").mean().reset_index()

# Align county home price dates to month-end
county_long["Month"] = county_long["PriceDate"] + pd.offsets.MonthEnd(0)

# Make RateDate == Month for merging
df_rates = df_rates.rename(columns={"RateDate": "Month"})
df_rates["Month"] = df_rates["Month"] + pd.offsets.MonthEnd(0)

# Merge county home prices + taxes
county_merged = pd.merge(
    county_long,
    tax_clean,
    on=["County", "Year"],
    how="left"
)

# DELETE old mortgage rate columns if they exist
for col in ["Mortgage Rate", "Mortgage Rate_x", "Mortgage Rate_y"]:
    if col in county_merged.columns:
        county_merged = county_merged.drop(columns=[col])

# Correct Single Merge for Mortgage Rate
county_merged = county_merged.merge(
    df_rates[["Month", "Mortgage Rate"]],
    on="Month",
    how="left"
)

# Add rent data
county_merged = pd.merge(
    county_merged,
    county_rent,
    on="County",
    how="left"
)
# Out:
# C:\Users\alexa\AppData\Local\Temp\ipykernel_3680\1166516973.py:7: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_rates = df_rates.resample("M", on="RateDate").mean().reset_index()

# %%
#county_merged

# %%
county_merged[county_merged["Year"] >= 2015].head(20)
# Out:
#       RegionID  SizeRank          RegionName RegionType StateName State  \
# 9172       581         6        Kings County     county        NY    NY
# 9173      1347        10       Queens County     county        NY    NY
# 9174      2452        20     New York County     county        NY    NY
# 9175      2046        24      Suffolk County     county        NY    NY
# 9176       401        26        Bronx County     county        NY    NY
# 9177      1252        29       Nassau County     county        NY    NY
# 9178      3148        48  Westchester County     county        NY    NY
# 9179       157        55         Erie County     county        NY    NY
# 9180      1223        87       Monroe County     county        NY    NY
# 9181      2511       143     Richmond County     county        NY    NY
# 9182      2465       150     Onondaga County     county        NY    NY
# 9183      1290       178       Orange County     county        NY    NY
# 9184      2515       211     Rockland County     county        NY    NY
# 9185       823       225       Albany County     county        NY    NY
# 9186      2255       235     Dutchess County     county        NY    NY
# 9187      2529       288     Saratoga County     county        NY    NY
# 9188      1283       293       Oneida County     county        NY    NY
# 9189      1946       319      Niagara County     county        NY    NY
# 9190       895       341       Broome County     county        NY    NY
# 9191      1448       369       Ulster County     county        NY    NY
#
#                                       Metro  StateCodeFIPS  MunicipalCodeFIPS  \
# 9172  New York-Newark-Jersey City, NY-NJ-PA             36                 47
# 9173  New York-Newark-Jersey City, NY-NJ-PA             36                 81
# 9174  New York-Newark-Jersey City, NY-NJ-PA             36                 61
# 9175  New York-Newark-Jersey City, NY-NJ-PA             36                103
# 9176  New York-Newark-Jersey City, NY-NJ-PA             36                  5
# 9177  New York-Newark-Jersey City, NY-NJ-PA             36                 59
# 9178  New York-Newark-Jersey City, NY-NJ-PA             36                119
# 9179                Buffalo-Cheektowaga, NY             36                 29
# 9180                          Rochester, NY             36                 55
# 9181  New York-Newark-Jersey City, NY-NJ-PA             36                 85
# 9182                           Syracuse, NY             36                 67
# 9183   Poughkeepsie-Newburgh-Middletown, NY             36                 71
# 9184  New York-Newark-Jersey City, NY-NJ-PA             36                 87
# 9185            Albany-Schenectady-Troy, NY             36                  1
# 9186   Poughkeepsie-Newburgh-Middletown, NY             36                 27
# 9187            Albany-Schenectady-Troy, NY             36                 91
# 9188                         Utica-Rome, NY             36                 65
# 9189                Buffalo-Cheektowaga, NY             36                 63
# 9190                         Binghamton, NY             36                  7
# 9191                           Kingston, NY             36                111
#
#       PriceDate      HomePrice       County  Year      Month  TaxAmount  \
# 9172 2015-01-31  411315.513185        Kings  2015 2015-01-31     2903.0
# 9173 2015-01-31  275119.382556       Queens  2015 2015-01-31     2914.0
# 9174 2015-01-31  833111.529246     New York  2015 2015-01-31     5873.0
# 9175 2015-01-31  188032.745783      Suffolk  2015 2015-01-31     7192.0
# 9176 2015-01-31  152386.498527        Bronx  2015 2015-01-31     2653.0
# 9177 2015-01-31  256284.902655       Nassau  2015 2015-01-31     8711.0
# 9178 2015-01-31  220162.386541  Westchester  2015 2015-01-31     9003.0
# 9179 2015-01-31   83662.742520         Erie  2015 2015-01-31     3120.0
# 9180 2015-01-31   73309.624571       Monroe  2015 2015-01-31     3805.0
# 9181 2015-01-31  236189.984726     Richmond  2015 2015-01-31     2842.0
# 9182 2015-01-31   77132.097251     Onondaga  2015 2015-01-31     3237.0
# 9183 2015-01-31   98182.629060       Orange  2015 2015-01-31     5586.0
# 9184 2015-01-31  169472.796362     Rockland  2015 2015-01-31     8268.0
# 9185 2015-01-31  109439.620470       Albany  2015 2015-01-31     3526.0
# 9186 2015-01-31  130477.010856     Dutchess  2015 2015-01-31     4873.0
# 9187 2015-01-31  152372.486733     Saratoga  2015 2015-01-31     3857.0
# 9188 2015-01-31   63537.339287       Oneida  2015 2015-01-31     2504.0
# 9189 2015-01-31   60260.133841      Niagara  2015 2015-01-31     2986.0
# 9190 2015-01-31   52456.922746       Broome  2015 2015-01-31     2417.0
# 9191 2015-01-31  127335.186715       Ulster  2015 2015-01-31     4208.0
#
#         TaxDate  Mortgage Rate   RentDate  Housing  MonthlyRent
# 9172 2015-01-01           3.67 2024-01-01  26251.0  2187.583333
# 9173 2015-01-01           3.67 2024-01-01  28178.0  2348.166667
# 9174 2015-01-01           3.67 2024-01-01  31371.0  2614.250000
# 9175 2015-01-01           3.67 2024-01-01  22245.0  1853.750000
# 9176 2015-01-01           3.67 2024-01-01  21130.0  1760.833333
# 9177 2015-01-01           3.67 2024-01-01  22295.0  1857.916667
# 9178 2015-01-01           3.67 2024-01-01  27604.0  2300.333333
# 9179 2015-01-01           3.67 2024-01-01  12016.0  1001.333333
# 9180 2015-01-01           3.67 2024-01-01  12754.0  1062.833333
# 9181 2015-01-01           3.67 2024-01-01  24853.0  2071.083333
# 9182 2015-01-01           3.67 2024-01-01  12062.0  1005.166667
# 9183 2015-01-01           3.67 2024-01-01  16102.0  1341.833333
# 9184 2015-01-01           3.67 2024-01-01  26869.0  2239.083333
# 9185 2015-01-01           3.67 2024-01-01  13098.0  1091.500000
# 9186 2015-01-01           3.67 2024-01-01  15298.0  1274.833333
# 9187 2015-01-01           3.67 2024-01-01  14092.0  1174.333333
# 9188 2015-01-01           3.67 2024-01-01  11383.0   948.583333
# 9189 2015-01-01           3.67 2024-01-01  10081.0   840.083333
# 9190 2015-01-01           3.67 2024-01-01  10472.0   872.666667
# 9191 2015-01-01           3.67 2024-01-01  16509.0  1375.750000

# %%
county_merged.to_csv("County_merges_clean.csv", index=False)

# %% [markdown]
# #### **Prepare data for Prophet**

# %%
prophet_df = county_merged[["County", "PriceDate", "HomePrice", "Mortgage Rate", "TaxAmount"]].copy()

# %%
prophet_df = prophet_df.rename(columns={"PriceDate": "ds",
    "HomePrice": "y",
    "Mortgage Rate": "mortgage_rate",
    "TaxAmount": "tax"})

prophet_df = prophet_df.sort_values(["County", "ds"])

# %%
prophet_df
# Out:
#        County         ds              y  mortgage_rate     tax
# 13     Albany 2000-01-31   68626.703404            NaN     NaN
# 64     Albany 2000-02-29   68611.125462            NaN     NaN
# 115    Albany 2000-03-31   68552.145087            NaN     NaN
# 166    Albany 2000-04-30   68857.608378            NaN     NaN
# 217    Albany 2000-05-31   68914.968717            NaN     NaN
# ...       ...        ...            ...            ...     ...
# 15658   Yates 2025-05-31  249297.963255         6.8160  2422.0
# 15710   Yates 2025-06-30  249031.402643         6.8175  2422.0
# 15762   Yates 2025-07-31  249771.492827         6.7200  2422.0
# 15814   Yates 2025-08-31  250514.609601         6.5875  2422.0
# 15866   Yates 2025-09-30  251084.712001         6.3525  2422.0
#
# [15867 rows x 5 columns]

# %% [markdown]
# #### **Build Prophet model**
# #### **Let's choose Kings County**

# %%
county_name = "Kings" #Here

df_county = prophet_df[prophet_df["County"] == county_name].dropna()

m = Prophet()

# Add regressors
m.add_regressor("mortgage_rate")
m.add_regressor("tax")

# Train model
m.fit(df_county)
# Out:
# 21:50:47 - cmdstanpy - INFO - Chain [1] start processing
# 21:50:48 - cmdstanpy - INFO - Chain [1] done processing

# %% [markdown]
# #### **Create future dataframe (next 60 months)**

# %%
future = m.make_future_dataframe(periods=60, freq='ME')  # 5-year forecast

# Add future regressors — use last known values forward
future["mortgage_rate"] = df_county["mortgage_rate"].iloc[-1]
future["tax"] = df_county["tax"].iloc[-1]

# %% [markdown]
# #### **Predict home prices**

# %%
forecast = m.predict(future)
forecast[["ds", "yhat", "yhat_lower", "yhat_upper"]].tail(12)
# Out:
#             ds           yhat     yhat_lower     yhat_upper
# 177 2029-10-31  772699.774190  732591.286504  813594.529612
# 178 2029-11-30  773647.490433  731574.937719  816456.450398
# 179 2029-12-31  776385.101753  734280.687531  821425.050343
# 180 2030-01-31  776298.809860  731864.834677  820314.715459
# 181 2030-02-28  778745.106295  733707.009167  823327.203045
# 182 2030-03-31  781292.493746  735579.310107  827352.748503
# 183 2030-04-30  784730.080214  738656.950020  831870.456946
# 184 2030-05-31  788481.818551  737899.799945  835524.038752
# 185 2030-06-30  791874.065983  741144.185676  840708.891779
# 186 2030-07-31  795157.990154  745149.830988  845721.539009
# 187 2030-08-31  797432.770278  745998.877993  850167.689702
# 188 2030-09-30  800333.317062  745960.233216  850585.314818

# %%
m.plot(forecast)
m.plot_components(forecast)

# %% [markdown]
# #### **Run Prophet for ALL counties**

# %%
# Prepare Prophet-ready data
prophet_df = county_merged[[
    "County", "PriceDate", "HomePrice",
    "Mortgage Rate", "TaxAmount"
]].copy()

prophet_df = prophet_df.rename(columns={
    "PriceDate": "ds",
    "HomePrice": "y",
    "Mortgage Rate": "mortgage_rate",
    "TaxAmount": "tax"
})

prophet_df = prophet_df.dropna()
prophet_df = prophet_df.sort_values(["County", "ds"])

# Store forecasts for each county
county_forecasts = {}

counties = prophet_df["County"].unique()

for county in counties:
    df_c = prophet_df[prophet_df["County"] == county]

    if len(df_c) < 24:
        continue  # Not enough data

    m = Prophet()
    m.add_regressor("mortgage_rate")
    m.add_regressor("tax")

    m.fit(df_c)

    # Create future dates
    future = m.make_future_dataframe(periods=60, freq="M")

    # Use last known values for regressors
    future["mortgage_rate"] = df_c["mortgage_rate"].iloc[-1]
    future["tax"] = df_c["tax"].iloc[-1]

    forecast = m.predict(future)
    forecast["County"] = county

    county_forecasts[county] = forecast

print("Done forecasting all counties!")
# Out:
# 21:50:50 - cmdstanpy - INFO - Chain [1] start processing
# 21:50:50 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:50:51 - cmdstanpy - INFO - Chain [1] start processing
# 21:50:51 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:50:51 - cmdstanpy - INFO - Chain [1] start processing
# 21:50:51 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:50:51 - cmdstanpy - INFO - Chain [1] start processing
# 21:50:51 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:50:52 - cmdstanpy - INFO - Chain [1] start processing
# 21:50:52 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:50:52 - cmdstanpy - INFO - Chain [1] start processing
# 21:50:52 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:50:53 - cmdstanpy - INFO - Chain [1] start processing
# 21:50:53 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:50:53 - cmdstanpy - INFO - Chain [1] start processing
# 21:50:53 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:50:53 - cmdstanpy - INFO - Chain [1] start processing
# 21:50:54 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:50:54 - cmdstanpy - INFO - Chain [1] start processing
# 21:50:54 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:50:54 - cmdstanpy - INFO - Chain [1] start processing
# 21:50:54 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:50:55 - cmdstanpy - INFO - Chain [1] start processing
# 21:50:55 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:50:55 - cmdstanpy - INFO - Chain [1] start processing
# 21:50:55 - cmdstanpy - INFO - Chain [1] done processing
# 21:50:55 - cmdstanpy - ERROR - Chain [1] error: code '1' Operation not permitted
# Optimization terminated abnormally. Falling back to Newton.
# 21:50:55 - cmdstanpy - INFO - Chain [1] start processing
# 21:50:58 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:50:58 - cmdstanpy - INFO - Chain [1] start processing
# 21:50:58 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:50:58 - cmdstanpy - INFO - Chain [1] start processing
# 21:50:58 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:50:59 - cmdstanpy - INFO - Chain [1] start processing
# 21:50:59 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:50:59 - cmdstanpy - INFO - Chain [1] start processing
# 21:50:59 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:51:00 - cmdstanpy - INFO - Chain [1] start processing
# 21:51:00 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:51:00 - cmdstanpy - INFO - Chain [1] start processing
# 21:51:00 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:51:01 - cmdstanpy - INFO - Chain [1] start processing
# 21:51:01 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:51:01 - cmdstanpy - INFO - Chain [1] start processing
# 21:51:01 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:51:02 - cmdstanpy - INFO - Chain [1] start processing
# 21:51:02 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:51:02 - cmdstanpy - INFO - Chain [1] start processing
# 21:51:02 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:51:02 - cmdstanpy - INFO - Chain [1] start processing
# 21:51:03 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:51:03 - cmdstanpy - INFO - Chain [1] start processing
# 21:51:03 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:51:04 - cmdstanpy - INFO - Chain [1] start processing
# 21:51:04 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:51:04 - cmdstanpy - INFO - Chain [1] start processing
# 21:51:05 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:51:05 - cmdstanpy - INFO - Chain [1] start processing
# 21:51:05 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:51:06 - cmdstanpy - INFO - Chain [1] start processing
# 21:51:06 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:51:07 - cmdstanpy - INFO - Chain [1] start processing
# 21:51:07 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:51:07 - cmdstanpy - INFO - Chain [1] start processing
# 21:51:07 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:51:08 - cmdstanpy - INFO - Chain [1] start processing
# 21:51:08 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:51:08 - cmdstanpy - INFO - Chain [1] start processing
# 21:51:08 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:51:09 - cmdstanpy - INFO - Chain [1] start processing
# 21:51:09 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:51:10 - cmdstanpy - INFO - Chain [1] start processing
# 21:51:10 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:51:10 - cmdstanpy - INFO - Chain [1] start processing
# 21:51:11 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:51:11 - cmdstanpy - INFO - Chain [1] start processing
# 21:51:11 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:51:12 - cmdstanpy - INFO - Chain [1] start processing
# 21:51:12 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:51:12 - cmdstanpy - INFO - Chain [1] start processing
# 21:51:12 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:51:12 - cmdstanpy - INFO - Chain [1] start processing
# 21:51:13 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:51:13 - cmdstanpy - INFO - Chain [1] start processing
# 21:51:13 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:51:13 - cmdstanpy - INFO - Chain [1] start processing
# 21:51:14 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:51:14 - cmdstanpy - INFO - Chain [1] start processing
# 21:51:14 - cmdstanpy - INFO - Chain [1] done processing
# 21:51:14 - cmdstanpy - ERROR - Chain [1] error: code '1' Operation not permitted
# Optimization terminated abnormally. Falling back to Newton.
# 21:51:14 - cmdstanpy - INFO - Chain [1] start processing
# 21:51:16 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:51:16 - cmdstanpy - INFO - Chain [1] start processing
# 21:51:16 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:51:17 - cmdstanpy - INFO - Chain [1] start processing
# 21:51:17 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:51:17 - cmdstanpy - INFO - Chain [1] start processing
# 21:51:17 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:51:18 - cmdstanpy - INFO - Chain [1] start processing
# 21:51:18 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:51:18 - cmdstanpy - INFO - Chain [1] start processing
# 21:51:18 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:51:19 - cmdstanpy - INFO - Chain [1] start processing
# 21:51:19 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:51:19 - cmdstanpy - INFO - Chain [1] start processing
# 21:51:19 - cmdstanpy - INFO - Chain [1] done processing
# 21:51:19 - cmdstanpy - ERROR - Chain [1] error: code '1' Operation not permitted
# Optimization terminated abnormally. Falling back to Newton.
# 21:51:19 - cmdstanpy - INFO - Chain [1] start processing
# 21:51:21 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:51:21 - cmdstanpy - INFO - Chain [1] start processing
# 21:51:21 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\alexa\AppData\Local\Programs\Python\Python313\Lib\site-packages\prophet\forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# Done forecasting all counties!

# %% [markdown]
# #### **Predict rent for 2025–2030**

# %%
rent_growth = 0.025  # we don’t have historical rent so let's assume 2.5% annual rent inflation per year

rent_forecasts = []

for county in county_rent["County"].unique():
    base_rent = county_rent[county_rent["County"] == county]["MonthlyRent"].iloc[0]

    for year in range(2025, 2031):  # 2025-2030
        future_rent = base_rent * ((1 + rent_growth) ** (year - 2024))

        rent_forecasts.append({
            "County": county,
            "Year": year,
            "MonthlyRentForecast": future_rent
        })

rent_forecasts = pd.DataFrame(rent_forecasts)

rent_forecasts
# Out:
#      County  Year  MonthlyRentForecast
# 0    Albany  2025          1118.787500
# 1    Albany  2026          1146.757187
# 2    Albany  2027          1175.426117
# 3    Albany  2028          1204.811770
# 4    Albany  2029          1234.932064
# ..      ...   ...                  ...
# 367   Yates  2026           802.852604
# 368   Yates  2027           822.923919
# 369   Yates  2028           843.497017
# 370   Yates  2029           864.584443
# 371   Yates  2030           886.199054
#
# [372 rows x 3 columns]

# %% [markdown]
# #### **Export everything to CSV**
# #### **5-year cost of renting vs 5-year cost of buying**

# %%
all_prophet = pd.concat(county_forecasts.values(), ignore_index=True)
all_prophet.to_csv("home_price_forecasts.csv", index=False)

# %%
rent_forecasts.to_csv("rent_forecasts.csv", index=False)

# %% [markdown]
# #### **Build the ML Model (Random Forest)**

# %%
ml_df = county_merged[[
    "HomePrice", "Mortgage Rate", "TaxAmount", "MonthlyRent", "Year"
]].dropna()

X = ml_df.drop(columns=["HomePrice"])
y = ml_df["HomePrice"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = RandomForestRegressor(n_estimators=300)
model.fit(X_train, y_train)

print("Model score:", model.score(X_test, y_test))
# Out:
# Model score: 0.9987860691969194

# %% [markdown]
# #### **County comparison plots**

# %%
county = "Kings"

df_plot = all_prophet[all_prophet["County"] == county]

plt.figure(figsize=(10,5))
plt.plot(df_plot["ds"], df_plot["yhat"])
plt.title(f"Home Price Forecast — {county}")
plt.ylabel("Price")
plt.xlabel("Year")
plt.grid(True)
plt.show()

# %% [markdown]
# #### **Just Check the data, we can delete it**

# %%
county_merged.head(20)
# Out:
#     RegionID  SizeRank          RegionName RegionType StateName State  \
# 0        581         6        Kings County     county        NY    NY
# 1       1347        10       Queens County     county        NY    NY
# 2       2452        20     New York County     county        NY    NY
# 3       2046        24      Suffolk County     county        NY    NY
# 4        401        26        Bronx County     county        NY    NY
# 5       1252        29       Nassau County     county        NY    NY
# 6       3148        48  Westchester County     county        NY    NY
# 7        157        55         Erie County     county        NY    NY
# 8       1223        87       Monroe County     county        NY    NY
# 9       2511       143     Richmond County     county        NY    NY
# 10      2465       150     Onondaga County     county        NY    NY
# 11      1290       178       Orange County     county        NY    NY
# 12      2515       211     Rockland County     county        NY    NY
# 13       823       225       Albany County     county        NY    NY
# 14      2255       235     Dutchess County     county        NY    NY
# 15      2529       288     Saratoga County     county        NY    NY
# 16      1283       293       Oneida County     county        NY    NY
# 17      1946       319      Niagara County     county        NY    NY
# 18       895       341       Broome County     county        NY    NY
# 19      1448       369       Ulster County     county        NY    NY
#
#                                     Metro  StateCodeFIPS  MunicipalCodeFIPS  \
# 0   New York-Newark-Jersey City, NY-NJ-PA             36                 47
# 1   New York-Newark-Jersey City, NY-NJ-PA             36                 81
# 2   New York-Newark-Jersey City, NY-NJ-PA             36                 61
# 3   New York-Newark-Jersey City, NY-NJ-PA             36                103
# 4   New York-Newark-Jersey City, NY-NJ-PA             36                  5
# 5   New York-Newark-Jersey City, NY-NJ-PA             36                 59
# 6   New York-Newark-Jersey City, NY-NJ-PA             36                119
# 7                 Buffalo-Cheektowaga, NY             36                 29
# 8                           Rochester, NY             36                 55
# 9   New York-Newark-Jersey City, NY-NJ-PA             36                 85
# 10                           Syracuse, NY             36                 67
# 11   Poughkeepsie-Newburgh-Middletown, NY             36                 71
# 12  New York-Newark-Jersey City, NY-NJ-PA             36                 87
# 13            Albany-Schenectady-Troy, NY             36                  1
# 14   Poughkeepsie-Newburgh-Middletown, NY             36                 27
# 15            Albany-Schenectady-Troy, NY             36                 91
# 16                         Utica-Rome, NY             36                 65
# 17                Buffalo-Cheektowaga, NY             36                 63
# 18                         Binghamton, NY             36                  7
# 19                           Kingston, NY             36                111
#
#     PriceDate      HomePrice       County  Year      Month  TaxAmount TaxDate  \
# 0  2000-01-31  117798.487679        Kings  2000 2000-01-31        NaN     NaT
# 1  2000-01-31  117354.466108       Queens  2000 2000-01-31        NaN     NaT
# 2  2000-01-31  258182.439226     New York  2000 2000-01-31        NaN     NaT
# 3  2000-01-31   91291.879450      Suffolk  2000 2000-01-31        NaN     NaT
# 4  2000-01-31   81662.035485        Bronx  2000 2000-01-31        NaN     NaT
# 5  2000-01-31  131162.307959       Nassau  2000 2000-01-31        NaN     NaT
# 6  2000-01-31  114825.799481  Westchester  2000 2000-01-31        NaN     NaT
# 7  2000-01-31   54579.383567         Erie  2000 2000-01-31        NaN     NaT
# 8  2000-01-31   57213.173289       Monroe  2000 2000-01-31        NaN     NaT
# 9  2000-01-31  111612.221545     Richmond  2000 2000-01-31        NaN     NaT
# 10 2000-01-31   47287.438230     Onondaga  2000 2000-01-31        NaN     NaT
# 11 2000-01-31   67217.926826       Orange  2000 2000-01-31        NaN     NaT
# 12 2000-01-31  110967.834694     Rockland  2000 2000-01-31        NaN     NaT
# 13 2000-01-31   68626.703404       Albany  2000 2000-01-31        NaN     NaT
# 14 2000-01-31   81451.071226     Dutchess  2000 2000-01-31        NaN     NaT
# 15 2000-01-31   71403.270017     Saratoga  2000 2000-01-31        NaN     NaT
# 16 2000-01-31   39471.972142       Oneida  2000 2000-01-31        NaN     NaT
# 17 2000-01-31   43003.442456      Niagara  2000 2000-01-31        NaN     NaT
# 18 2000-01-31   30114.535896       Broome  2000 2000-01-31        NaN     NaT
# 19 2000-01-31   83390.339061       Ulster  2000 2000-01-31        NaN     NaT
#
#     Mortgage Rate   RentDate  Housing  MonthlyRent
# 0             NaN 2024-01-01  26251.0  2187.583333
# 1             NaN 2024-01-01  28178.0  2348.166667
# 2             NaN 2024-01-01  31371.0  2614.250000
# 3             NaN 2024-01-01  22245.0  1853.750000
# 4             NaN 2024-01-01  21130.0  1760.833333
# 5             NaN 2024-01-01  22295.0  1857.916667
# 6             NaN 2024-01-01  27604.0  2300.333333
# 7             NaN 2024-01-01  12016.0  1001.333333
# 8             NaN 2024-01-01  12754.0  1062.833333
# 9             NaN 2024-01-01  24853.0  2071.083333
# 10            NaN 2024-01-01  12062.0  1005.166667
# 11            NaN 2024-01-01  16102.0  1341.833333
# 12            NaN 2024-01-01  26869.0  2239.083333
# 13            NaN 2024-01-01  13098.0  1091.500000
# 14            NaN 2024-01-01  15298.0  1274.833333
# 15            NaN 2024-01-01  14092.0  1174.333333
# 16            NaN 2024-01-01  11383.0   948.583333
# 17            NaN 2024-01-01  10081.0   840.083333
# 18            NaN 2024-01-01  10472.0   872.666667
# 19            NaN 2024-01-01  16509.0  1375.750000

# %%
county_merged.tail(20)
# Out:
#        RegionID  SizeRank          RegionName RegionType StateName State  \
# 15847      1630       715      Clinton County     county        NY    NY
# 15848      3088       732  Cattaraugus County     county        NY    NY
# 15849       929       738       Cayuga County     county        NY    NY
# 15850      1909       790      Madison County     county        NY    NY
# 15851      1479       827       Warren County     county        NY    NY
# 15852      2961       861   Livingston County     county        NY    NY
# 15853      2214       869     Columbia County     county        NY    NY
# 15854      3066       870   Washington County     county        NY    NY
# 15855      2340       878     Herkimer County     county        NY    NY
# 15856      1298       890       Otsego County     county        NY    NY
# 15857      1722       902      Genesee County     county        NY    NY
# 15858      1024       954       Fulton County     county        NY    NY
# 15859      2979      1012   Montgomery County     county        NY    NY
# 15860       748      1026        Tioga County     county        NY    NY
# 15861      2287      1037     Franklin County     county        NY    NY
# 15862      2224      1050     Cortland County     county        NY    NY
# 15863      1954      1191      Orleans County     county        NY    NY
# 15864      1373      1369       Seneca County     county        NY    NY
# 15865      2843      1472    Schoharie County     county        NY    NY
# 15866       816      1663        Yates County     county        NY    NY
#
#                              Metro  StateCodeFIPS  MunicipalCodeFIPS  \
# 15847              Plattsburgh, NY             36                 19
# 15848                    Olean, NY             36                  9
# 15849                   Auburn, NY             36                 11
# 15850                 Syracuse, NY             36                 53
# 15851              Glens Falls, NY             36                113
# 15852                Rochester, NY             36                 51
# 15853                   Hudson, NY             36                 21
# 15854              Glens Falls, NY             36                115
# 15855               Utica-Rome, NY             36                 43
# 15856                  Oneonta, NY             36                 77
# 15857                  Batavia, NY             36                 37
# 15858             Gloversville, NY             36                 35
# 15859                Amsterdam, NY             36                 57
# 15860               Binghamton, NY             36                107
# 15861                   Malone, NY             36                 33
# 15862                 Cortland, NY             36                 23
# 15863                Rochester, NY             36                 73
# 15864             Seneca Falls, NY             36                 99
# 15865  Albany-Schenectady-Troy, NY             36                 95
# 15866                Rochester, NY             36                123
#
#        PriceDate      HomePrice       County  Year      Month  TaxAmount  \
# 15847 2025-09-30  131762.195956      Clinton  2025 2025-09-30     2341.0
# 15848 2025-09-30  124117.196275  Cattaraugus  2025 2025-09-30     2054.0
# 15849 2025-09-30  179549.977339       Cayuga  2025 2025-09-30     2550.0
# 15850 2025-09-30  159390.136985      Madison  2025 2025-09-30     2766.0
# 15851 2025-09-30  207548.197830       Warren  2025 2025-09-30     2525.0
# 15852 2025-09-30  157235.519704   Livingston  2025 2025-09-30     3062.0
# 15853 2025-09-30  318202.333871     Columbia  2025 2025-09-30     3605.0
# 15854 2025-09-30  172526.672478   Washington  2025 2025-09-30     2875.0
# 15855 2025-09-30  139757.371779     Herkimer  2025 2025-09-30     2097.0
# 15856 2025-09-30  139482.683735       Otsego  2025 2025-09-30     2053.0
# 15857 2025-09-30  118273.155243      Genesee  2025 2025-09-30     2818.0
# 15858 2025-09-30  131734.984728       Fulton  2025 2025-09-30     2262.0
# 15859 2025-09-30  129445.465055   Montgomery  2025 2025-09-30     2713.0
# 15860 2025-09-30  106864.762269        Tioga  2025 2025-09-30     2354.0
# 15861 2025-09-30  114533.230389     Franklin  2025 2025-09-30     1848.0
# 15862 2025-09-30  126422.998496     Cortland  2025 2025-09-30     2747.0
# 15863 2025-09-30  127532.907261      Orleans  2025 2025-09-30     2873.0
# 15864 2025-09-30  201504.481440       Seneca  2025 2025-09-30     1674.0
# 15865 2025-09-30  160676.221062    Schoharie  2025 2025-09-30     1974.0
# 15866 2025-09-30  251084.712001        Yates  2025 2025-09-30     2422.0
#
#          TaxDate  Mortgage Rate   RentDate  Housing  MonthlyRent
# 15847 2025-01-01         6.3525 2024-01-01  11387.0   948.916667
# 15848 2025-01-01         6.3525 2024-01-01   8833.0   736.083333
# 15849 2025-01-01         6.3525 2024-01-01   9881.0   823.416667
# 15850 2025-01-01         6.3525 2024-01-01  10073.0   839.416667
# 15851 2025-01-01         6.3525 2024-01-01  13045.0  1087.083333
# 15852 2025-01-01         6.3525 2024-01-01  10330.0   860.833333
# 15853 2025-01-01         6.3525 2024-01-01  14111.0  1175.916667
# 15854 2025-01-01         6.3525 2024-01-01  11979.0   998.250000
# 15855 2025-01-01         6.3525 2024-01-01  10067.0   838.916667
# 15856 2025-01-01         6.3525 2024-01-01   9785.0   815.416667
# 15857 2025-01-01         6.3525 2024-01-01   8977.0   748.083333
# 15858 2025-01-01         6.3525 2024-01-01   9580.0   798.333333
# 15859 2025-01-01         6.3525 2024-01-01   9218.0   768.166667
# 15860 2025-01-01         6.3525 2024-01-01  10472.0   872.666667
# 15861 2025-01-01         6.3525 2024-01-01   8122.0   676.833333
# 15862 2025-01-01         6.3525 2024-01-01  10797.0   899.750000
# 15863 2025-01-01         6.3525 2024-01-01   9933.0   827.750000
# 15864 2025-01-01         6.3525 2024-01-01   9881.0   823.416667
# 15865 2025-01-01         6.3525 2024-01-01   9583.0   798.583333
# 15866 2025-01-01         6.3525 2024-01-01   9170.0   764.166667

# %%
county_merged.columns
# Out:
# Index(['RegionID', 'SizeRank', 'RegionName', 'RegionType', 'StateName',
#        'State', 'Metro', 'StateCodeFIPS', 'MunicipalCodeFIPS', 'PriceDate',
#        'HomePrice', 'County', 'Year', 'Month', 'TaxAmount', 'TaxDate',
#        'Mortgage Rate', 'RentDate', 'Housing', 'MonthlyRent'],
#       dtype='object')

# %%
county_merged.isna().sum()
# Out:
# RegionID                0
# SizeRank                0
# RegionName              0
# RegionType              0
# StateName               0
# State                   0
# Metro                   0
# StateCodeFIPS           0
# MunicipalCodeFIPS       0
# PriceDate               0
# HomePrice               0
# County                  0
# Year                    0
# Month                   0
# TaxAmount            9301
# TaxDate              9301
# Mortgage Rate        9172
# RentDate              309
# Housing               309
# MonthlyRent           309
# dtype: int64

# %%
county_merged.columns.duplicated().sum()
# Out:
# np.int64(0)

# %%
county_merged.duplicated().sum()
# Out:
# np.int64(0)
